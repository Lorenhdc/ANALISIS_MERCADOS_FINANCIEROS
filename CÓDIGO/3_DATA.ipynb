# %%
import pandas as pd

# %%
XLY = pd.read_csv("Consumer Discretionary (XLY).csv")

# %%
XLP = pd.read_csv("Consumer Staples Select Sector SPDR (XLP).csv")

# %%
FDN = pd.read_csv("DJ Internet Index Fund (FDN).csv")

# %%
XLE = pd.read_csv("Energy Select Sector SPDR (XLE).csv")

# %%
XLF = pd.read_csv("Financial Select Sector SPDR Fund (XLF).csv")

# %%
XLV = pd.read_csv("Health Care Select Sector SPDR (XLV).csv")

# %%
XLI = pd.read_csv("Industrial Select Sector SPDR (XLI).csv")

# %%
IGF = pd.read_csv("iShares Global Infrastructure ETF (IGF).csv")

# %%
IBB = pd.read_csv("iShares Nasdaq Biotechnology ETF (IBB).csv")

# %%
IYT = pd.read_csv("iShares Transportation Average ETF (IYT).csv")

# %%
ITB = pd.read_csv("iShares U.S. Home Construction ETF (ITB).csv")

# %%
IYZ = pd.read_csv("iShares US Telecommunications ETF (IYZ).csv")

# %%
GDX = pd.read_csv("Market Vectors TR Gold Miners (GDX).csv")

# %%
XLB = pd.read_csv("Materials Select Sector SPDR (XLB).csv")

# %%
KBE = pd.read_csv("SPDR S&P Bank ETF (KBE).csv")

# %%
XLK = pd.read_csv("Technology Select Sector SPDR (XLK).csv")

# %%
XLU = pd.read_csv("Utilities Select Sector SPDR (XLU).csv")

# %%
VOX = pd.read_csv("Vanguard Communication Services ETF (VOX).csv")

# %%
VCR = pd.read_csv("Vanguard Consumer Discretionary (VCR).csv")

# %%
VDC = pd.read_csv("Vanguard Consumer Staples ETF (VDC).csv")

# %%
VDE = pd.read_csv("Vanguard Energy ETF (VDE).csv")

# %%
VFH = pd.read_csv("Vanguard Financials ETF (VFH).csv")

# %%
VHT = pd.read_csv("Vanguard Health Care ETF (VHT).csv")

# %%
VIS = pd.read_csv("Vanguard Industrials ETF (VIS).csv")

# %%
VGT = pd.read_csv("Vanguard Information Tech ETF (VGT).csv")

# %%
VNQ = pd.read_csv("Vanguard REIT ETF (VNQ).csv")

# %%
VPU = pd.read_csv("Vanguard Utilities ETF (VPU).csv")

# %%
DATASETS_ETF = pd.concat([XLY, VCR, XLP, VDC, XLE, VDE, XLF, VFH, KBE, XLV, IBB, VHT, XLI, VIS, IYT, XLK, VGT, FDN, XLB, GDX, ITB, VNQ, VOX, IYZ, XLU, VPU, IGF], axis=0)

# %%
del DATASETS_ETG

# %%
DATASETS_ETF = pd.read_csv("DATASETS_etf.csv")

# %%
DATASETS_ETF.reset_index(inplace=True, drop=True)

# %%
DATASETS_ETF
# Out:
#              Date                                   NOMBRE  AREA TIPO  \
# 0      2021-12-26             Consumer Discretionary (XLY)  EEUU  ETF
# 1      2021-12-19             Consumer Discretionary (XLY)  EEUU  ETF
# 2      2021-12-12             Consumer Discretionary (XLY)  EEUU  ETF
# 3      2021-12-05             Consumer Discretionary (XLY)  EEUU  ETF
# 4      2021-11-28             Consumer Discretionary (XLY)  EEUU  ETF
# ...           ...                                      ...   ...  ...
# 27197  2008-01-13  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27198  2008-01-06  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27199  2007-12-30  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27200  2007-12-23  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27201  2007-12-16  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
#
#                    SECTOR  PRECIO  PRECIO NORMALIADO MAX  \
# 0                 CONSUMO  204.44             966.985148
# ...

# %%
del SP500
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lherrera/Desktop/Bootcamp_ds/Alumno/2-Data_Analysis/Entregas/EDA/BORRADORES/ETFS/INVESTING/COMPLETADOS/DATA.ipynb Cell 34' in <module>
# ----> <a href='vscode-notebook-cell:/Users/lherrera/Desktop/Bootcamp_ds/Alumno/2-Data_Analysis/Entregas/EDA/BORRADORES/ETFS/INVESTING/COMPLETADOS/DATA.ipynb#ch0000054?line=0'>1</a> del SP500
#
# NameError: name 'SP500' is not defined

# %%
DAX = pd.read_csv("DAX.csv")

# %%
DOW = pd.read_csv("DOW JONES INDUSTRIAL.csv")

# %%
EURO = pd.read_csv("EURONEXT 100.csv")

# %%
GOLD = pd.read_csv("GOLD SPOT US DOLLAR.csv")

# %%
IBEX = pd.read_csv("IBEX 35.csv")

# %%
NASDAQ = pd.read_csv("NASDAQ 100.csv")

# %%
NYSE = pd.read_csv("NYSE COMPOSITE.csv")

# %%
SP500 = pd.read_csv("S&P 500.csv")

# %%
DATASETS_INDEX = pd.concat([DAX, DOW, EURO, GOLD, IBEX, NASDAQ, NYSE, SP500], axis=0)

# %%
DATASETS_INDEX.reset_index(inplace=True, drop=True)

# %%
DATASETS_INDEX
# Out:
#              Date   NOMBRE    AREA    TIPO  SECTOR    PRECIO  \
# 0      2022-03-06      DAX  EUROPA  INDICE     NaN  13087.13
# 1      2022-02-27      DAX  EUROPA  INDICE     NaN  13094.54
# 2      2022-02-20      DAX  EUROPA  INDICE     NaN  14567.23
# 3      2022-02-13      DAX  EUROPA  INDICE     NaN  15042.51
# 4      2022-02-06      DAX  EUROPA  INDICE     NaN  15425.12
# ...           ...      ...     ...     ...     ...       ...
# 17317  1970-02-01  S&P 500    EEUU  INDICE     NaN     86.33
# 17318  1970-01-25  S&P 500    EEUU  INDICE     NaN     85.02
# 17319  1970-01-18  S&P 500    EEUU  INDICE     NaN     89.37
# 17320  1970-01-11  S&P 500    EEUU  INDICE     NaN     90.92
# 17321  1970-01-04  S&P 500    EEUU  INDICE     NaN     92.40
#
#        PRECIO NORMALIADO MAX  PRECIO NORMALIADO MIN  PRECIO SEMANAL  \
# 0                 809.848657              13.981976        13094.54
# 1                 810.307197              13.989893        14567.23
# ...

# %%
DATASETS_INDEX.drop(['PRECIO SEMANAL', 'PRECIO MENSUAL', 'PRECIO ANUAL','PRECIO BIANUAL','PRECIO LUSTRO','PRECIO LUSTRO A','PRECIO 2 ANIO A','PRECIO ANIO A','PRECIO SEMESTRAL A'],inplace=True, axis=1)

# %%
DATASETS_ETF.drop(['PRECIO SEMANAL', 'PRECIO MENSUAL', 'PRECIO ANUAL','PRECIO BIANUAL','PRECIO LUSTRO','PRECIO LUSTRO A','PRECIO 2 ANIO A','PRECIO ANIO A','PRECIO SEMESTRAL A'],inplace=True, axis=1)

# %%
DATASETS_INDEX.groupby('NOMBRE')['RENTABILIDAD ANUAL'].mean()
# Out:
# NOMBRE
# DAX                             0.105548
# DOW JONES INDUSTRIAL AVERAGE    0.089522
# EURONEXT 100                    0.030005
# GOLD SPOT US DOLLAR             0.107119
# IBEX 35                         0.067781
# NADAQ 100                       0.176441
# NYSE COMPOSITE                  0.084011
# S&P500                          0.093327
# Name: RENTABILIDAD ANUAL, dtype: float64

# %%
DATASETS_ETF[DATASETS_ETF['RENTABILIDAD SEMANAL']<-0.10]
# Out:
#              Date                                   NOMBRE  AREA TIPO  \
# 93     2020-03-15             Consumer Discretionary (XLY)  EEUU  ETF
# 94     2020-03-08             Consumer Discretionary (XLY)  EEUU  ETF
# 96     2020-02-23             Consumer Discretionary (XLY)  EEUU  ETF
# 688    2008-10-19             Consumer Discretionary (XLY)  EEUU  ETF
# 690    2008-10-05             Consumer Discretionary (XLY)  EEUU  ETF
# ...           ...                                      ...   ...  ...
# 26562  2020-03-15  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 26563  2020-03-08  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 26565  2020-02-23  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27159  2008-10-05  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
# 27160  2008-09-28  iShares Global Infrastructure ETF (IGF)  EEUU  ETF
#
#                    SECTOR  PRECIO  PRECIO NORMALIADO MAX  \
# 93                CONSUMO   87.81             415.334405
# ...

# %%
DATASETS_ETF.to_csv("DATASETS_etf.csv", index = False)

# %%
DATASETS_INDEX.to_csv("DATASETS_indice.csv", index = False)

# %%
DATASETS_ANALISIS = pd.concat([DATASETS_INDEX, DATASETS_ETF], axis=0)

# %%
DATASETS_ANALISIS
# Out:
#              Date                                   NOMBRE    AREA    TIPO  \
# 0      2022-03-06                                      DAX  EUROPA  INDICE
# 1      2022-02-27                                      DAX  EUROPA  INDICE
# 2      2022-02-20                                      DAX  EUROPA  INDICE
# 3      2022-02-13                                      DAX  EUROPA  INDICE
# 4      2022-02-06                                      DAX  EUROPA  INDICE
# ...           ...                                      ...     ...     ...
# 27197  2008-01-13  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 27198  2008-01-06  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 27199  2007-12-30  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 27200  2007-12-23  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 27201  2007-12-16  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
#
#                    SECTOR    PRECIO  PRECIO NORMALIADO MAX  \
# ...

# %%
DATASETS_ANALISIS.reset_index(inplace=True, drop=True)

# %%
DATASETS_ANALISIS
# Out:
#              Date                                   NOMBRE    AREA    TIPO  \
# 0      2022-03-06                                      DAX  EUROPA  INDICE
# 1      2022-02-27                                      DAX  EUROPA  INDICE
# 2      2022-02-20                                      DAX  EUROPA  INDICE
# 3      2022-02-13                                      DAX  EUROPA  INDICE
# 4      2022-02-06                                      DAX  EUROPA  INDICE
# ...           ...                                      ...     ...     ...
# 44519  2008-01-13  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44520  2008-01-06  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44521  2007-12-30  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44522  2007-12-23  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44523  2007-12-16  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
#
#                    SECTOR    PRECIO  PRECIO NORMALIADO MAX  \
# ...

# %%
DATASETS_ANALISIS.set_index("Date", inplace=True)

# %%
pd.set_option("display.max_rows", 9999)

# %%
DATASETS_ANALISIS.head()
# Out:
#            NOMBRE    AREA    TIPO SECTOR    PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2022-03-06    DAX  EUROPA  INDICE    NaN  13087.13             809.848657
# 2022-02-27    DAX  EUROPA  INDICE    NaN  13094.54             810.307197
# 2022-02-20    DAX  EUROPA  INDICE    NaN  14567.23             901.439173
# 2022-02-13    DAX  EUROPA  INDICE    NaN  15042.51             930.850119
# 2022-02-06    DAX  EUROPA  INDICE    NaN  15425.12             954.526524
#
#             PRECIO NORMALIADO MIN  RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  \
# Date
# 2022-03-06              13.981976             -0.000566             -0.151570
# 2022-02-27              13.989893             -0.101096             -0.132787
# 2022-02-20              15.563280             -0.031596             -0.049071
# 2022-02-13              16.071058             -0.024804             -0.035976
# 2022-02-06              16.479829              0.021561             -0.028843
#
# ...

# %%
DATASETS_ANALISIS.to_csv("DATASETS_analisis.csv", index = True)
