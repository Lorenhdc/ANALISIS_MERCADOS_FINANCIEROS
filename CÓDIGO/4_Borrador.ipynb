# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("DATASETS_analisis.csv")

# %%
counted = pd.pivot_table(df, values ='PRECIO', columns = 'SECTOR',index='Date')
precio = counted.dropna(how='any')
precio
# Out:
# SECTOR      COMUNICACION   CONSUMO  ENERGIA  FINANCIERO   INDUSTRIA  \
# Date
# 2004-10-03        37.335   38.1350   43.680   37.205000   46.030000
# 2004-10-10        37.130   38.0450   42.305   36.480000   45.923333
# 2004-10-17        36.180   38.0000   42.840   35.585000   45.790000
# 2004-10-24        36.825   38.9175   42.235   37.090000   47.263333
# 2004-10-31        38.135   40.5300   43.040   38.045000   48.660000
# ...                  ...       ...      ...         ...         ...
# 2021-11-28        81.275  197.5625   66.080   61.980000  186.963333
# 2021-12-05        83.050  203.1775   68.730   63.430000  192.473333
# 2021-12-12        82.695  197.4900   64.755   62.030000  187.263333
# 2021-12-19        84.655  202.8950   65.915   62.996667  192.250000
# 2021-12-26        84.235  205.5225   66.555   63.393333  195.083333
#
# SECTOR      INMOBILIARIO   MATERIAS   SANITARIO  SERVICIOS PUBLICOS  \
# Date
# ...

# %%
df
# Out:
#                                              NOMBRE    AREA    TIPO  \
# Date
# 2022-03-06                                      DAX  EUROPA  INDICE
# 2022-02-27                                      DAX  EUROPA  INDICE
# 2022-02-20                                      DAX  EUROPA  INDICE
# 2022-02-13                                      DAX  EUROPA  INDICE
# 2022-02-06                                      DAX  EUROPA  INDICE
# ...                                             ...     ...     ...
# 2008-01-13  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 2008-01-06  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 2007-12-30  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 2007-12-23  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 2007-12-16  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
#
#                         SECTOR    PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2022-03-06                 NaN  13087.13             809.848657
# ...

# %%
counted = pd.pivot_table(df, values ='PRECIO', columns = 'NOMBRE',index='Date')
rentabilidad_semanal = counted.dropna(how='any')
rentabilidad_semanal
# Out:
# NOMBRE      Consumer Discretionary (XLY)  \
# Date
# 2007-12-16                         32.94
# 2007-12-23                         32.82
# 2007-12-30                         30.84
# 2008-01-06                         30.26
# 2008-01-13                         29.52
# ...                                  ...
# 2021-11-28                        199.65
# 2021-12-05                        204.99
# 2021-12-12                        195.29
# 2021-12-19                        203.19
# 2021-12-26                        204.44
#
# NOMBRE      Consumer Staples Select Sector SPDR (XLP)       DAX  \
# Date
# 2007-12-16                                      29.34   8002.67
# 2007-12-23                                      29.03   8067.32
# 2007-12-30                                      28.12   7808.69
# 2008-01-06                                      28.27   7717.95
# 2008-01-13                                      27.15   7314.17
# ...                                               ...       ...
# ...

# %%
df['NOMBRE'].unique()
# Out:
# array(['DAX', 'DOW JONES INDUSTRIAL', 'EURONEXT 100',
#        'GOLD SPOT US DOLLAR', 'IBEX 35', 'NASDAQ 100', 'NYSE COMPOSITE',
#        'S&P 500', 'Consumer Discretionary (XLY)',
#        'Vanguard Consumer Discretionary (VCR)',
#        'Consumer Staples Select Sector SPDR (XLP)',
#        'Vanguard Consumer Staples ETF (VDC)',
#        'Energy Select Sector SPDR (XLE)', 'Vanguard Energy ETF (VDE)',
#        'Financial Select Sector SPDR Fund (XLF)',
#        'Vanguard Financials ETF (VFH)', 'SPDR S&P Bank ETF (KBE)',
#        'Health Care Select Sector SPDR (XLV)',
#        'iShares Nasdaq Biotechnology ETF (IBB)',
#        'Vanguard Health Care ETF (VHT)',
#        'Industrial Select Sector SPDR (XLI)',
#        'Vanguard Industrials ETF (VIS)',
#        'iShares Transportation Average ETF (IYT)',
#        'Technology Select Sector SPDR (XLK)',
#        'Vanguard Information Tech ETF (VGT)',
#        'DJ Internet Index Fund (FDN)',
#        'Materials Select Sector SPDR (XLB)',
# ...

# %%
df
# Out:
#              Date                                   NOMBRE    AREA    TIPO  \
# 0      2022-03-06                                      DAX  EUROPA  INDICE
# 1      2022-02-27                                      DAX  EUROPA  INDICE
# 2      2022-02-20                                      DAX  EUROPA  INDICE
# 3      2022-02-13                                      DAX  EUROPA  INDICE
# 4      2022-02-06                                      DAX  EUROPA  INDICE
# ...           ...                                      ...     ...     ...
# 44519  2008-01-13  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44520  2008-01-06  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44521  2007-12-30  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44522  2007-12-23  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
# 44523  2007-12-16  iShares Global Infrastructure ETF (IGF)    EEUU     ETF
#
#                    SECTOR    PRECIO  PRECIO NORMALIADO MAX  \
# ...

# %%
df_rent_semanal = pd.read_csv('Rentabilidad semanal.csv')

# %%
df_rent_semanal['Date'] = pd.to_datetime(df_rent_semanal['Date'], format="%Y-%m-%d")
df_rent_semanal
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df_rent_semanal
# Out:
#             RENTABILIDAD SEMANAL DAX  RENTABILIDAD SEMANAL DOW  \
# Date
# 2022-02-27                 -0.101096                 -0.013033
# 2022-02-20                 -0.031596                 -0.000604
# 2022-02-13                 -0.024804                 -0.018952
# 2022-02-06                  0.021561                 -0.010039
# 2022-01-30                 -0.014321                  0.010490
# ...                              ...                       ...
# 2000-01-30                  0.053492                  0.020945
# 2000-01-23                  0.010561                 -0.045579
# 2000-01-16                 -0.025159                 -0.040200
# 2000-01-09                  0.057847                  0.017394
# 2000-01-02                 -0.025464                  0.002213
#
#             RENTABILIDAD SEMANAL EURO100  RENTABILIDAD SEMANAL GOLD  \
# Date
# 2022-02-27                     -0.090919                   0.042854
# ...

# %%
df_2020 = df.loc['03-2019':'12-2021']
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2386517179.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_2020 = df.loc['03-2019':'12-2021']

# %%
df['Date'] = pd.to_datetime(df['Date'], format="%Y-%m-%d")
df.set_index('Date', inplace=True)

# %%
# CALCULO DOW
df_2020_DOW = df_2020[df_2020['NOMBRE']=='DOW JONES INDUSTRIAL']
df_2020_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_DOW['PRECIO NORMALIZADO MIN'] = df_2020_DOW['PRECIO']*100/df_2020_DOW['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2191821998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2191821998.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_DOW['PRECIO NORMALIZADO MIN'] = df_2020_DOW['PRECIO']*100/df_2020_DOW['PRECIO'].min()

# %%
# CALCULO DAX
df_2020_DAX = df_2020[df_2020['NOMBRE']=='DAX']
df_2020_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_DAX['PRECIO NORMALIZADO MIN'] = df_2020_DAX['PRECIO']*100/df_2020_DAX['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2369498380.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2369498380.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_DAX['PRECIO NORMALIZADO MIN'] = df_2020_DAX['PRECIO']*100/df_2020_DAX['PRECIO'].min()

# %%
# CALCULO EURO
df_2020_EURO = df_2020[df_2020['NOMBRE']=='EURONEXT 100']
df_2020_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_EURO['PRECIO NORMALIZADO MIN'] = df_2020_EURO['PRECIO']*100/df_2020_EURO['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2428607699.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2428607699.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_EURO['PRECIO NORMALIZADO MIN'] = df_2020_EURO['PRECIO']*100/df_2020_EURO['PRECIO'].min()

# %%
# CALCULO IBEX
df_2020_IBEX = df_2020[df_2020['NOMBRE']=='IBEX 35']
df_2020_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_IBEX['PRECIO NORMALIZADO MIN'] = df_2020_IBEX['PRECIO']*100/df_2020_IBEX['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3935926054.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3935926054.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_IBEX['PRECIO NORMALIZADO MIN'] = df_2020_IBEX['PRECIO']*100/df_2020_IBEX['PRECIO'].min()

# %%
# CALCULO NASDAQ
df_2020_NASDAQ = df_2020[df_2020['NOMBRE']=='NASDAQ 100']
df_2020_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2020_NASDAQ['PRECIO']*100/df_2020_NASDAQ['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/4175752387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/4175752387.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2020_NASDAQ['PRECIO']*100/df_2020_NASDAQ['PRECIO'].min()

# %%
# CALCULO NYSE
df_2020_NYSE = df_2020[df_2020['NOMBRE']=='NYSE COMPOSITE']
df_2020_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_NYSE['PRECIO NORMALIZADO MIN'] = df_2020_NYSE['PRECIO']*100/df_2020_NYSE['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/6833041.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/6833041.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_NYSE['PRECIO NORMALIZADO MIN'] = df_2020_NYSE['PRECIO']*100/df_2020_NYSE['PRECIO'].min()

# %%
#CÁLCULO S&P
df_2020_SP = df_2020[df_2020['NOMBRE']=='S&P 500']
df_2020_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_SP['PRECIO NORMALIZADO MIN'] = df_2020_SP['PRECIO']*100/df_2020_SP['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3447343589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3447343589.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_SP['PRECIO NORMALIZADO MIN'] = df_2020_SP['PRECIO']*100/df_2020_SP['PRECIO'].min()

# %%
# CÁLCULO ORO
df_2020_GOLD = df_2020[df_2020['NOMBRE']=='GOLD SPOT US DOLLAR']
df_2020_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2020_GOLD['PRECIO NORMALIZADO MIN'] = df_2020_GOLD['PRECIO']*100/df_2020_GOLD['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2109982216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2109982216.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_GOLD['PRECIO NORMALIZADO MIN'] = df_2020_GOLD['PRECIO']*100/df_2020_GOLD['PRECIO'].min()

# %%
df_2019_final = pd.concat([df_2020_GOLD,df_2020_SP,df_2020_NYSE,df_2020_NASDAQ,df_2020_IBEX,df_2020_EURO,df_2020_DAX,df_2020_DOW],axis=0)

# %%
df_2019_final
# Out:
#                           NOMBRE  AREA            TIPO SECTOR    PRECIO  \
# Date
# 2021-12-26   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1828.39
# 2021-12-19   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1808.11
# 2021-12-12   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1797.68
# 2021-12-05   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1782.51
# 2021-11-28   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1783.74
# ...                          ...   ...             ...    ...       ...
# 2019-03-31  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  26424.99
# 2019-03-24  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  25928.68
# 2019-03-17  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  25502.32
# 2019-03-10  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  25848.87
# 2019-03-03  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  25450.24
#
#             RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  RENTABILIDAD ANUAL  \
# Date
# ...

# %%
df_2020_final
# Out:
#                           NOMBRE  AREA            TIPO SECTOR    PRECIO  \
# Date
# 2020-12-27   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1898.10
# 2020-12-20   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1875.82
# 2020-12-13   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1880.66
# 2020-12-06   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1839.03
# 2020-11-29   GOLD SPOT US DOLLAR   NaN  TIPO DE CAMBIO    NaN   1837.61
# ...                          ...   ...             ...    ...       ...
# 2020-03-29  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  21052.53
# 2020-03-22  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  21636.78
# 2020-03-15  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  19173.98
# 2020-03-08  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  23185.62
# 2020-03-01  DOW JONES INDUSTRIAL  EEUU          INDICE    NaN  25864.78
#
#             RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  RENTABILIDAD ANUAL  \
# Date
# ...

# %% [markdown]
# ## CRISIS COVID-19

# %%
df_2020_DOW.plot()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1027682586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_DOW['PRECIO NORMALIZADO MIN'] = df_2020_DOW['PRECIO']*100/df_2020_DOW['PRECIO'].min()
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(30,30))
df_2020_DOW.plot(y='PRECIO NORMALIZADO MIN')
df_2020_DAX.plot(y='PRECIO NORMALIZADO MIN')
df_2020_IBEX.plot(y='PRECIO NORMALIZADO MIN')
df_2020_EURO.plot(y='PRECIO NORMALIZADO MIN')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# MATPLOTLIB
plt.figure(figsize=(10,10))
df_2019_final[df_2019_final['NOMBRE']=='DAX']['PRECIO NORMALIZADO MIN'].plot(style='-', color = 'black', label = 'DAX')
df_2019_final[df_2019_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO NORMALIZADO MIN'].plot(style=':', color = 'blue',label = 'DOW')
df_2019_final[df_2019_final['NOMBRE']=='EURONEXT 100']['PRECIO NORMALIZADO MIN'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2019_final[df_2019_final['NOMBRE']=='IBEX 35']['PRECIO NORMALIZADO MIN'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2019_final[df_2019_final['NOMBRE']=='NASDAQ 100']['PRECIO NORMALIZADO MIN'].plot(color = 'red',label = 'NASDAQ')
df_2019_final[df_2019_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO NORMALIZADO MIN'].plot(color = 'cyan',label = 'NYSE')
df_2019_final[df_2019_final['NOMBRE']=='S&P 500']['PRECIO NORMALIZADO MIN'].plot(color = 'purple',label = 'S&P 500')
df_2019_final[df_2019_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO NORMALIZADO MIN'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(60,10))
df_2019_final[df_2019_final['NOMBRE']=='DAX']['RENTABILIDAD MENSUAL'].plot(style='-', color = 'black' )
df_2019_final[df_2019_final['NOMBRE']=='DOW JONES INDUSTRIAL']['RENTABILIDAD MENSUAL'].plot(style=':', color = 'blue')
df_2019_final[df_2019_final['NOMBRE']=='EURONEXT 100']['RENTABILIDAD MENSUAL'].plot(style='--', color = 'pink')
df_2019_final[df_2019_final['NOMBRE']=='IBEX 35']['RENTABILIDAD MENSUAL'].plot(style='-.', color = 'olive')
df_2019_final[df_2019_final['NOMBRE']=='NASDAQ 100']['RENTABILIDAD MENSUAL'].plot(color = 'red')
df_2019_final[df_2019_final['NOMBRE']=='NYSE COMPOSITE']['RENTABILIDAD MENSUAL'].plot(color = 'cyan')
df_2019_final[df_2019_final['NOMBRE']=='S&P 500']['RENTABILIDAD MENSUAL'].plot(color = 'purple')
df_2019_final[df_2019_final['NOMBRE']=='GOLD SPOT US DOLLAR']['RENTABILIDAD MENSUAL'].plot(color = 'green');

# %%
plt.figure(figsize=(10,10))
df_2019_final[df_2019_final['NOMBRE']=='DAX']['PRECIO'].plot(style='-', color = 'black', label = 'DAX')
df_2019_final[df_2019_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO'].plot(style=':', color = 'blue',label = 'DOW')
df_2019_final[df_2019_final['NOMBRE']=='EURONEXT 100']['PRECIO'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2019_final[df_2019_final['NOMBRE']=='IBEX 35']['PRECIO'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2019_final[df_2019_final['NOMBRE']=='NASDAQ 100']['PRECIO'].plot(color = 'red',label = 'NASDAQ')
df_2019_final[df_2019_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO'].plot(color = 'cyan',label = 'NYSE')
df_2019_final[df_2019_final['NOMBRE']=='S&P 500']['PRECIO'].plot(color = 'purple',label = 'S&P 500')
df_2019_final[df_2019_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
DF_1=df[df['TIPO']=='INDICE'].sort_values(by='RENTABILIDAD MENSUAL')

# SEMANA DEL 10/05/2008
#DF_1['2008'].head(50)
# SEMANA DEL 08/03/2020 EN EUROPA Y 15/03/2020 EN EEUU
#DF_1['2020'].head(50)
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/79080356.py:4: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   DF_1['2008'].head(50)
#                           NOMBRE    AREA    TIPO SECTOR    PRECIO  \
# Date
# 2008-10-19        NYSE COMPOSITE    EEUU  INDICE    NaN   5427.50
# 2008-10-05        NYSE COMPOSITE    EEUU  INDICE    NaN   5704.10
# 2008-10-19                   DAX  EUROPA  INDICE    NaN   4295.67
# 2008-10-05               S&P 500    EEUU  INDICE    NaN    899.22
# 2008-10-05            NASDAQ 100    EEUU  INDICE    NaN   1269.80
# 2008-10-05          EURONEXT 100  EUROPA  INDICE    NaN    543.36
# 2008-10-19            NASDAQ 100    EEUU  INDICE    NaN   1202.27
# 2008-10-19               S&P 500    EEUU  INDICE    NaN    876.77
# ...

# %%
df_rent_lustro.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_rent_lustro.to_csv('df_rent_lustro.csv',index=False)

# %%
# Indicame la correlación del ORO con respecto los demás indices. Poner hincapié en aquellos períodos de rentabilidad negativa para los índices.

# %%
rent_mensual = pd.read_csv('rentabilidad mensual.csv')

# %%
rent_mensual.rename(columns={'RENTABILIDAD MENSUAL DAX':'DAX','RENTABILIDAD MENSUAL DOW':'DOW','RENTABILIDAD MENSUAL EURO100':'EURO100','RENTABILIDAD MENSUAL GOLD':'GOLD','RENTABILIDAD MENSUAL IBEX':'IBEX','RENTABILIDAD MENSUAL NASDAQ':'NASDAQ','RENTABILIDAD MENSUAL NYSE':'NYSE','RENTABILIDAD MENSUAL S&P500':'S&P500'},inplace=True)

# %%
rent_semanal['Date'] = pd.to_datetime(rent_semanal['Date'], format="%Y-%m-%d")
rent_semanal.set_index('Date',inplace=True)

# %%
rent_semanal_COVID = rent_semanal['2020-03-01':'2020-12-31']
rent_semanal_COVID
# Out:
#                  DAX       DOW   EURO100      GOLD      IBEX    NASDAQ  \
# Date
# 2020-12-27  0.009682  0.013464  0.002999  0.011877 -0.004660  0.013946
# 2020-12-20 -0.003175  0.000690 -0.000336 -0.002574  0.009219 -0.002133
# 2020-12-13  0.039362  0.004416  0.005757  0.022637 -0.003187  0.029314
# 2020-12-06 -0.013885 -0.005688 -0.012890  0.000773 -0.031215 -0.012218
# 2020-11-29 -0.002754  0.010294  0.005004  0.027671  0.016140  0.022048
# 2020-11-22  0.015104  0.022106  0.017724 -0.044031  0.026674  0.029545
# 2020-11-15  0.004629 -0.007338  0.014698 -0.009295  0.024950 -0.002630
# 2020-11-08  0.047812  0.040829  0.066698 -0.032524  0.132933 -0.012696
# 2020-11-01  0.079915  0.068743  0.075700  0.039170  0.064815  0.093948
# 2020-10-25 -0.086137 -0.064723 -0.050063 -0.012016 -0.064003 -0.054703
# 2020-10-18 -0.020392 -0.009464 -0.011180  0.000958  0.006380 -0.013466
# 2020-10-11 -0.010899  0.000679 -0.002486 -0.015787 -0.014559  0.010773
# ...

# %%
rent_mensual['Date'] = pd.to_datetime(rent_mensual['Date'], format="%Y-%m-%d")
rent_mensual.set_index('Date',inplace=True)

# %%
rent_mensual
# Out:
#                  DAX       DOW   EURO100      GOLD      IBEX    NASDAQ  \
# Date
# 2022-02-27 -0.132787 -0.042037 -0.112275  0.089052 -0.101103 -0.058289
# 2022-02-20 -0.049071 -0.019205 -0.024649  0.053896 -0.014309 -0.018364
# 2022-02-13 -0.035976 -0.005436 -0.024448  0.035255 -0.012042 -0.029703
# 2022-02-06 -0.028843 -0.032701 -0.024181  0.023519 -0.000965 -0.086971
# 2022-01-30 -0.053185 -0.031517 -0.041511  0.006605 -0.018568 -0.057583
# ...              ...       ...       ...       ...       ...       ...
# 2000-01-30  0.097870 -0.048492  0.070507  0.118722  0.043027  0.097680
# 2000-01-23  0.015587 -0.065950       NaN -0.019081 -0.054298 -0.070580
# 2000-01-16  0.031016 -0.013505       NaN  0.004692 -0.061378  0.072329
# 2000-01-09  0.128948  0.041355       NaN  0.000705 -0.036950  0.102647
# 2000-01-02  0.112016  0.026535       NaN  0.009676 -0.029044  0.101871
#
#                 NYSE    S&P500
# Date
# 2022-02-27 -0.034242 -0.038144
# 2022-02-20  0.001836 -0.010657
# ...

# %%
rent_mensual_COVID = rent_mensual['2020-03-01':'2020-12-31']
rent_mensual_COVID
# Out:
#                  DAX       DOW   EURO100      GOLD      IBEX    NASDAQ  \
# Date
# 2020-12-27  0.031568  0.012847 -0.004564  0.032918 -0.029941  0.028719
# 2020-12-20  0.018863  0.009679 -0.002575  0.049040 -0.009670  0.036939
# 2020-12-13  0.037547  0.031287  0.015445  0.005437  0.007458  0.069856
# 2020-12-06  0.002874  0.019219  0.024472 -0.025958  0.035896  0.036654
# 2020-11-29  0.065620  0.066901  0.107072 -0.058365  0.211414  0.036152
# 2020-11-22  0.153957  0.128625  0.184948 -0.047829  0.269443  0.109044
# 2020-11-15  0.038867  0.032747  0.106024 -0.015941  0.157324  0.018291
# 2020-11-08  0.012993  0.030535  0.077816 -0.005756  0.136356  0.007228
# 2020-11-01 -0.043767 -0.009218  0.007911  0.011444 -0.011581  0.031170
# 2020-10-25 -0.089255 -0.042669 -0.035686 -0.010929 -0.044755 -0.018012
# 2020-10-18  0.014159  0.042747  0.037499  0.021903  0.039995  0.048555
# 2020-10-11 -0.015802  0.034309  0.008425 -0.026014 -0.011559  0.083678
# ...

# %%
sns.heatmap(rent_mensual.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(rent_mensual_COVID.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
rent_mensual.to_csv('rentabilidad_mensual1.csv')

# %%
rent_semanal = pd.read_csv('rentabilidad semanal.csv')

# %%
rent_semanal.rename(columns={'RENTABILIDAD SEMANAL DAX':'DAX','RENTABILIDAD SEMANAL DOW':'DOW','RENTABILIDAD SEMANAL EURO100':'EURO100','RENTABILIDAD SEMANAL GOLD':'GOLD','RENTABILIDAD SEMANAL IBEX':'IBEX','RENTABILIDAD SEMANAL NASDAQ':'NASDAQ','RENTABILIDAD SEMANAL NYSE':'NYSE','RENTABILIDAD SEMANAL S&P500':'S&P500'},inplace=True)

# %%
sns.heatmap(rent_semanal.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(rent_semanal_COVID.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
#¿SE CONSIDERA VALOR SEGURO O REFUGIO? Sí, porque sus movimientos a diferencia del resto de índices. Se correlacionan de manera diferente.

# %% [markdown]
# ## CRISIS DEL 2008

# %%
df_2008 = df.loc['01-2007':'12-2013']
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2438410121.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_2008 = df.loc['01-2007':'12-2013']

# %%
#CÁLCULO S&P
df_2008_SP = df_2008[df_2008['NOMBRE']=='S&P 500']
df_2008_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_SP['PRECIO NORMALIZADO MIN'] = df_2020_SP['PRECIO']*100/df_2020_SP['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/744322454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/744322454.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_SP['PRECIO NORMALIZADO MIN'] = df_2020_SP['PRECIO']*100/df_2020_SP['PRECIO'].min()

# %%
# CALCULO DOW
df_2008_DOW = df_2008[df_2008['NOMBRE']=='DOW JONES INDUSTRIAL']
df_2008_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_DOW['PRECIO NORMALIZADO MIN'] = df_2008_DOW['PRECIO']*100/df_2008_DOW['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1894416953.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1894416953.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_DOW['PRECIO NORMALIZADO MIN'] = df_2008_DOW['PRECIO']*100/df_2008_DOW['PRECIO'].min()

# %%
# CALCULO DAX
df_2008_DAX = df_2008[df_2008['NOMBRE']=='DAX']
df_2008_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_DAX['PRECIO NORMALIZADO MIN'] = df_2008_DAX['PRECIO']*100/df_2008_DAX['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2230028142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2230028142.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_DAX['PRECIO NORMALIZADO MIN'] = df_2008_DAX['PRECIO']*100/df_2008_DAX['PRECIO'].min()

# %%
#CALCULO EURO
df_2008_EURO = df_2008[df_2008['NOMBRE']=='EURONEXT 100']
df_2008_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_EURO['PRECIO NORMALIZADO MIN'] = df_2008_EURO['PRECIO']*100/df_2008_EURO['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2465450279.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2465450279.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_EURO['PRECIO NORMALIZADO MIN'] = df_2008_EURO['PRECIO']*100/df_2008_EURO['PRECIO'].min()

# %%
# CALCULO NYSE
df_2008_NYSE = df_2008[df_2008['NOMBRE']=='NYSE COMPOSITE']
df_2008_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_NYSE['PRECIO NORMALIZADO MIN'] = df_2008_NYSE['PRECIO']*100/df_2008_NYSE['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/28913632.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/28913632.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_NYSE['PRECIO NORMALIZADO MIN'] = df_2008_NYSE['PRECIO']*100/df_2008_NYSE['PRECIO'].min()

# %%
# CALCULO NASDAQ
df_2008_NASDAQ = df_2008[df_2008['NOMBRE']=='NASDAQ 100']
df_2008_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2008_NASDAQ['PRECIO']*100/df_2008_NASDAQ['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2879348217.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2879348217.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2008_NASDAQ['PRECIO']*100/df_2008_NASDAQ['PRECIO'].min()

# %%
# CALCULO IBEX
df_2008_IBEX = df_2008[df_2008['NOMBRE']=='IBEX 35']
df_2008_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_IBEX['PRECIO NORMALIZADO MIN'] = df_2008_IBEX['PRECIO']*100/df_2008_IBEX['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/810482851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/810482851.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_IBEX['PRECIO NORMALIZADO MIN'] = df_2008_IBEX['PRECIO']*100/df_2008_IBEX['PRECIO'].min()

# %%
# CÁLCULO GOLD
df_2008_GOLD = df_2008[df_2008['NOMBRE']=='GOLD SPOT US DOLLAR']
df_2008_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2008_GOLD['PRECIO NORMALIZADO MIN'] = df_2008_GOLD['PRECIO']*100/df_2008_GOLD['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/426366717.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/426366717.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2008_GOLD['PRECIO NORMALIZADO MIN'] = df_2008_GOLD['PRECIO']*100/df_2008_GOLD['PRECIO'].min()

# %%
df_2008_final = pd.concat([df_2008_GOLD,df_2008_SP,df_2008_NYSE,df_2008_NASDAQ,df_2008_IBEX,df_2008_EURO,df_2008_DAX,df_2008_DOW],axis=0)

# %%
plt.figure(figsize=(10,10))
df_2008_final[df_2008_final['NOMBRE']=='DAX']['PRECIO'].plot(style='-', color = 'black', label = 'DAX')
df_2008_final[df_2008_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO'].plot(style=':', color = 'blue',label = 'DOW')
df_2008_final[df_2008_final['NOMBRE']=='EURONEXT 100']['PRECIO'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2008_final[df_2008_final['NOMBRE']=='IBEX 35']['PRECIO'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2008_final[df_2008_final['NOMBRE']=='NASDAQ 100']['PRECIO'].plot(color = 'red',label = 'NASDAQ')
df_2008_final[df_2008_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO'].plot(color = 'cyan',label = 'NYSE')
df_2008_final[df_2008_final['NOMBRE']=='S&P 500']['PRECIO'].plot(color = 'purple',label = 'S&P 500')
df_2008_final[df_2008_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
# MATPLOTLIB
plt.figure(figsize=(10,10))
df_2008_final[df_2008_final['NOMBRE']=='DAX']['PRECIO NORMALIZADO MIN'].plot(style='-', color = 'black', label = 'DAX')
df_2008_final[df_2008_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO NORMALIZADO MIN'].plot(style=':', color = 'blue',label = 'DOW')
df_2008_final[df_2008_final['NOMBRE']=='EURONEXT 100']['PRECIO NORMALIZADO MIN'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2008_final[df_2008_final['NOMBRE']=='IBEX 35']['PRECIO NORMALIZADO MIN'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2008_final[df_2008_final['NOMBRE']=='NASDAQ 100']['PRECIO NORMALIZADO MIN'].plot(color = 'red',label = 'NASDAQ')
df_2008_final[df_2008_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO NORMALIZADO MIN'].plot(color = 'cyan',label = 'NYSE')
df_2008_final[df_2008_final['NOMBRE']=='S&P 500']['PRECIO NORMALIZADO MIN'].plot(color = 'purple',label = 'S&P 500')
df_2008_final[df_2008_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO NORMALIZADO MIN'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(60,10))
df_2008_final[df_2008_final['NOMBRE']=='DAX']['RENTABILIDAD MENSUAL'].plot(style='-', color = 'black' )
df_2008_final[df_2008_final['NOMBRE']=='DOW JONES INDUSTRIAL']['RENTABILIDAD MENSUAL'].plot(style=':', color = 'blue')
df_2008_final[df_2008_final['NOMBRE']=='EURONEXT 100']['RENTABILIDAD MENSUAL'].plot(style='--', color = 'pink')
df_2008_final[df_2008_final['NOMBRE']=='IBEX 35']['RENTABILIDAD MENSUAL'].plot(style='-.', color = 'olive')
df_2008_final[df_2008_final['NOMBRE']=='NASDAQ 100']['RENTABILIDAD MENSUAL'].plot(color = 'red')
df_2008_final[df_2008_final['NOMBRE']=='NYSE COMPOSITE']['RENTABILIDAD MENSUAL'].plot(color = 'cyan')
df_2008_final[df_2008_final['NOMBRE']=='S&P 500']['RENTABILIDAD MENSUAL'].plot(color = 'purple')
df_2008_final[df_2008_final['NOMBRE']=='GOLD SPOT US DOLLAR']['RENTABILIDAD MENSUAL'].plot(color = 'green');

# %%
rent_mensual_2008 = rent_mensual['2008-03-01':'2013-12-31']
rent_mensual_2008
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/453053910.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   rent_mensual_2008 = rent_mensual['2008-03-01':'2013-12-31']
#                  DAX       DOW   EURO100      GOLD      IBEX    NASDAQ  \
# Date
# 2013-12-29  0.028645  0.028076  0.030010  0.006266  0.042285  0.009837
# 2013-12-22  0.019573  0.024368  0.003219 -0.032150  0.006353  0.024715
# 2013-12-15  0.019648  0.009734 -0.012930 -0.032446  0.001292  0.031902
# 2013-12-08 -0.017694 -0.012927 -0.047602 -0.040115 -0.043647  0.009881
# 2013-12-01  0.010369  0.016395 -0.023308 -0.046072 -0.035569  0.040816
# ...              ...       ...       ...       ...       ...       ...
# 2008-03-30  0.038287  0.060177  0.051510 -0.061742  0.091015  0.092750
# 2008-03-23 -0.027894 -0.004075 -0.025359 -0.043271  0.020652  0.012777
# ...

# %%
rent_semanal_2008 = rent_semanal['2008-03-01':'2013-12-31']
rent_semanal_2008
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1681068359.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   rent_semanal_2008 = rent_semanal['2008-03-01':'2013-12-31']
#                  DAX       DOW   EURO100      GOLD      IBEX    NASDAQ  \
# Date
# 2013-12-29 -0.016084 -0.000511 -0.003370  0.019255 -0.010313 -0.009874
# 2013-12-22  0.020128  0.015860  0.019719  0.008261  0.021693  0.012129
# 2013-12-15  0.043715  0.029563  0.032261 -0.028305  0.044992  0.021638
# 2013-12-08 -0.018092 -0.016532 -0.018167  0.007690 -0.013595 -0.013658
# 2013-12-01 -0.024762 -0.004116 -0.029293 -0.019657 -0.044432  0.004714
# ...              ...       ...       ...       ...       ...       ...
# 2008-03-30  0.031020  0.032172  0.045097 -0.018379  0.030054  0.055613
# 2008-03-23  0.037961 -0.011724  0.031376  0.011854  0.036886  0.008893
# ...

# %%
sns.heatmap(rent_semanal_2008.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(rent_mensual_2008.corr(),vmin=-1,
            vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
df[df['TIPO']=='INDICE']['NOMBRE'].unique()
# Out:
# array(['DAX', 'DOW JONES INDUSTRIAL', 'EURONEXT 100', 'IBEX 35',
#        'NASDAQ 100', 'NYSE COMPOSITE', 'S&P 500'], dtype=object)

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='S&P 500']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#              NOMBRE  AREA    TIPO SECTOR  PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2007-10-07  S&P 500  EEUU  INDICE    NaN  1561.8             327.683805
#
#             PRECIO NORMALIADO MIN  RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  \
# Date
# 2007-10-07              25.052936              0.002703              0.052249
#
#             RENTABILIDAD ANUAL  RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  \
# Date
# 2007-10-07            0.143656              0.316231             0.869703
#
#             A 6 MESES  A 1 ANIO  A 2 ANIOS  A 5 ANIOS
# Date
# 2007-10-07  -0.039166 -0.424241  -0.313939  -0.085293

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='NYSE COMPOSITE']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#                     NOMBRE  AREA    TIPO SECTOR   PRECIO  \
# Date
# 2007-10-07  NYSE COMPOSITE  EEUU  INDICE    NaN  10301.5
#
#             PRECIO NORMALIADO MAX  PRECIO NORMALIADO MIN  \
# Date
# 2007-10-07             595.541604               29.61052
#
#             RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  RENTABILIDAD ANUAL  \
# Date
# 2007-10-07               0.00523              0.064898            0.191545
#
#             RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  A 6 MESES  A 1 ANIO  \
# Date
# 2007-10-07              0.399166             1.166593  -0.037004 -0.446285
#
#             A 2 ANIOS  A 5 ANIOS
# Date
# 2007-10-07  -0.318983  -0.201369

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='DAX']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#            NOMBRE    AREA    TIPO SECTOR   PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2007-07-08    DAX  EUROPA  INDICE    NaN  8092.77             500.791152
#
#             PRECIO NORMALIADO MIN  RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  \
# Date
# 2007-07-08               8.646122              0.005523              0.007737
#
#             RENTABILIDAD ANUAL  RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  \
# Date
# 2007-07-08             0.49252              0.717153             0.959129
#
#             A 6 MESES  A 1 ANIO  A 2 ANIOS  A 5 ANIOS
# Date
# 2007-07-08  -0.026928 -0.239655  -0.434519  -0.189758

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='DOW JONES INDUSTRIAL']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#                           NOMBRE  AREA    TIPO SECTOR    PRECIO  \
# Date
# 2007-10-07  DOW JONES INDUSTRIAL  EEUU  INDICE    NaN  14093.08
#
#             PRECIO NORMALIADO MAX  PRECIO NORMALIADO MIN  \
# Date
# 2007-10-07              387.82992              24.399377
#
#             RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  RENTABILIDAD ANUAL  \
# Date
# 2007-10-07              0.001924              0.048396            0.178301
#
#             RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  A 6 MESES  A 1 ANIO  \
# Date
# 2007-10-07              0.369944              0.79523  -0.040521 -0.400331
#
#             A 2 ANIOS  A 5 ANIOS
# Date
# 2007-10-07  -0.300015  -0.054227

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='EURONEXT 100']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#                   NOMBRE    AREA    TIPO SECTOR   PRECIO  \
# Date
# 2007-05-27  EURONEXT 100  EUROPA  INDICE    NaN  1076.12
#
#             PRECIO NORMALIADO MAX  PRECIO NORMALIADO MIN  \
# Date
# 2007-05-27             782.149217               2.466807
#
#             RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  RENTABILIDAD ANUAL  \
# Date
# 2007-05-27              0.017127                0.0197            0.271363
#
#             RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  A 6 MESES  A 1 ANIO  \
# Date
# 2007-05-27              0.518571              0.42837  -0.040246 -0.171171
#
#             A 2 ANIOS  A 5 ANIOS
# Date
# 2007-05-27  -0.478608  -0.476722

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='IBEX 35']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#              NOMBRE    AREA    TIPO SECTOR   PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2007-10-28  IBEX 35  EUROPA  INDICE    NaN  15823.7                 1000.0
#
#             PRECIO NORMALIADO MIN  RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  \
# Date
# 2007-10-28               8.083999              0.014086              0.062557
#
#             RENTABILIDAD ANUAL  RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  \
# Date
# 2007-10-28            0.147085              0.519712             1.577402
#
#             A 6 MESES  A 1 ANIO  A 2 ANIOS  A 5 ANIOS
# Date
# 2007-10-28  -0.005846 -0.423902  -0.278626  -0.496395

# %%
df_20081 = df.loc['2006':'2008']
df_20081 = df_20081[df_20081['NOMBRE']=='NASDAQ 100']
df_20081[df_20081['PRECIO']==df_20081['PRECIO'].max()]
# Out:
#                 NOMBRE  AREA    TIPO SECTOR   PRECIO  PRECIO NORMALIADO MAX  \
# Date
# 2007-10-28  NASDAQ 100  EEUU  INDICE    NaN  2213.86             133.579592
#
#             PRECIO NORMALIADO MIN  RENTABILIDAD SEMANAL  RENTABILIDAD MENSUAL  \
# Date
# 2007-10-28              20.111374              0.008781               0.02986
#
#             RENTABILIDAD ANUAL  RENTABILIDAD BIANUAL  RENTABILIDAD LUSTRO  \
# Date
# 2007-10-28            0.299229               0.35984             1.172453
#
#             A 6 MESES  A 1 ANIO  A 2 ANIOS  A 5 ANIOS
# Date
# 2007-10-28  -0.081107  -0.39708  -0.246958   0.199841

# %% [markdown]
# ## COMPORTAMIENTO 2000

# %%
df_2000 = df.loc['03-2000':'12-2015']
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3423244361.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_2000 = df.loc['03-2000':'12-2015']

# %%
df[df['TIPO']=='INDICE']['NOMBRE'].unique()
# Out:
# array(['DAX', 'DOW JONES INDUSTRIAL', 'EURONEXT 100', 'IBEX 35',
#        'NASDAQ 100', 'NYSE COMPOSITE', 'S&P 500'], dtype=object)

# %%
# CALCULO NYSE
df_2000_NYSE = df_2000[df_2000['NOMBRE']=='NYSE COMPOSITE']
df_2000_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_NYSE['PRECIO NORMALIZADO MIN'] = df_2000_NYSE['PRECIO']*100/df_2000_NYSE['PRECIO'].min();
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1668718392.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_NYSE.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1668718392.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_NYSE['PRECIO NORMALIZADO MIN'] = df_2000_NYSE['PRECIO']*100/df_2000_NYSE['PRECIO'].min();

# %%
# CALCULO DOW
df_2000_DOW = df_2000[df_2000['NOMBRE']=='DOW JONES INDUSTRIAL']
df_2000_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_DOW['PRECIO NORMALIZADO MIN'] = df_2000_DOW['PRECIO']*100/df_2000_DOW['PRECIO'].min();
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1990099071.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_DOW.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1990099071.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_DOW['PRECIO NORMALIZADO MIN'] = df_2000_DOW['PRECIO']*100/df_2000_DOW['PRECIO'].min();

# %%
# CALCULO DAX
df_2000_DAX = df_2000[df_2000['NOMBRE']=='DAX']
df_2000_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_DAX['PRECIO NORMALIZADO MIN'] = df_2000_DAX['PRECIO']*100/df_2000_DAX['PRECIO'].min();
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2017549221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_DAX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2017549221.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_DAX['PRECIO NORMALIZADO MIN'] = df_2000_DAX['PRECIO']*100/df_2000_DAX['PRECIO'].min();

# %%
# CALCULO EURO
df_2000_EURO = df_2000[df_2000['NOMBRE']=='DAX']
df_2000_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_EURO['PRECIO NORMALIZADO MIN'] = df_2000_EURO['PRECIO']*100/df_2000_EURO['PRECIO'].min();
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2591026635.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_EURO.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/2591026635.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_EURO['PRECIO NORMALIZADO MIN'] = df_2000_EURO['PRECIO']*100/df_2000_EURO['PRECIO'].min();

# %%
# CALCULO IBEX
df_2000_IBEX = df_2000[df_2000['NOMBRE']=='IBEX 35']
df_2000_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_IBEX['PRECIO NORMALIZADO MIN'] = df_2000_IBEX['PRECIO']*100/df_2000_IBEX['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3217111094.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_IBEX.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3217111094.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_IBEX['PRECIO NORMALIZADO MIN'] = df_2000_IBEX['PRECIO']*100/df_2000_IBEX['PRECIO'].min()

# %%
# CALCULO ORO
df_2000_GOLD = df_2000[df_2000['NOMBRE']=='GOLD SPOT US DOLLAR']
df_2000_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_GOLD['PRECIO NORMALIZADO MIN'] = df_2000_GOLD['PRECIO']*100/df_2000_GOLD['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3319428558.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_GOLD.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/3319428558.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_GOLD['PRECIO NORMALIZADO MIN'] = df_2000_GOLD['PRECIO']*100/df_2000_GOLD['PRECIO'].min()

# %%
# CALCULO NASDAQ
df_2000_NASDAQ = df_2000[df_2000['NOMBRE']=='NASDAQ 100']
df_2000_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2000_NASDAQ['PRECIO']*100/df_2000_NASDAQ['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1197427848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_NASDAQ.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1197427848.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_NASDAQ['PRECIO NORMALIZADO MIN'] = df_2000_NASDAQ['PRECIO']*100/df_2000_NASDAQ['PRECIO'].min()

# %%
#CÁLCULO S&P
df_2000_SP = df_2000[df_2000['NOMBRE']=='S&P 500']
df_2000_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
df_2000_SP['PRECIO NORMALIZADO MIN'] = df_2000_SP['PRECIO']*100/df_2000_SP['PRECIO'].min()
# Out:
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1992705835.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_SP.drop(['PRECIO NORMALIADO MAX','PRECIO NORMALIADO MIN'],inplace=True, axis=1)
# /var/folders/xg/mm8z7nf57pbbnsfb9kynnv4m0000gn/T/ipykernel_2314/1992705835.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000_SP['PRECIO NORMALIZADO MIN'] = df_2000_SP['PRECIO']*100/df_2000_SP['PRECIO'].min()

# %%
df_2000_final = pd.concat([df_2000_GOLD,df_2000_SP,df_2000_NYSE,df_2000_NASDAQ,df_2000_IBEX,df_2000_EURO,df_2000_DAX,df_2000_DOW],axis=0)

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='DAX']['PRECIO NORMALIZADO MIN'].plot(style='-', color = 'black', label = 'DAX')
df_2000_final[df_2000_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO NORMALIZADO MIN'].plot(style=':', color = 'blue',label = 'DOW')
df_2000_final[df_2000_final['NOMBRE']=='EURONEXT 100']['PRECIO NORMALIZADO MIN'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2000_final[df_2000_final['NOMBRE']=='IBEX 35']['PRECIO NORMALIZADO MIN'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2000_final[df_2000_final['NOMBRE']=='NASDAQ 100']['PRECIO NORMALIZADO MIN'].plot(color = 'red',label = 'NASDAQ')
df_2000_final[df_2000_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO NORMALIZADO MIN'].plot(color = 'cyan',label = 'NYSE')
df_2000_final[df_2000_final['NOMBRE']=='S&P 500']['PRECIO NORMALIZADO MIN'].plot(color = 'purple',label = 'S&P 500')
df_2000_final[df_2000_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO NORMALIZADO MIN'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='DAX']['PRECIO'].plot(style='-', color = 'black', label = 'DAX')
df_2000_final[df_2000_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO'].plot(style=':', color = 'blue',label = 'DOW')
df_2000_final[df_2000_final['NOMBRE']=='EURONEXT 100']['PRECIO'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df_2000_final[df_2000_final['NOMBRE']=='IBEX 35']['PRECIO'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df_2000_final[df_2000_final['NOMBRE']=='NASDAQ 100']['PRECIO'].plot(color = 'red',label = 'NASDAQ')
df_2000_final[df_2000_final['NOMBRE']=='NYSE COMPOSITE']['PRECIO'].plot(color = 'cyan',label = 'NYSE')
df_2000_final[df_2000_final['NOMBRE']=='S&P 500']['PRECIO'].plot(color = 'purple',label = 'S&P 500')
df_2000_final[df_2000_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO'].plot(style=':', color = 'blue',label = 'DOW')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='DAX']['PRECIO'].plot(style='-', color = 'black', label = 'DAX')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))

df_2000_final[df_2000_final['NOMBRE']=='IBEX 35']['PRECIO'].plot(style='-.', color = 'olive',label = 'IBEX 35')

plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))

df_2000_final[df_2000_final['NOMBRE']=='NASDAQ 100']['PRECIO'].plot(color = 'red',label = 'NASDAQ')

plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='S&P 500']['PRECIO'].plot(color = 'purple',label = 'S&P 500')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %%
plt.figure(figsize=(10,10))
df_2000_final[df_2000_final['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);

# %% [markdown]
# ## Aquí se ve la teoría del interés compuesto

# %%
plt.figure(figsize=(10,10))
df[df['NOMBRE']=='DAX']['PRECIO'].plot(style='-', color = 'black', label = 'DAX')
df[df['NOMBRE']=='DOW JONES INDUSTRIAL']['PRECIO'].plot(style=':', color = 'blue',label = 'DOW')
df[df['NOMBRE']=='EURONEXT 100']['PRECIO'].plot(style='--', color = 'pink',label = 'EURONEXT100')
df[df['NOMBRE']=='IBEX 35']['PRECIO'].plot(style='-.', color = 'olive',label = 'IBEX 35')
df[df['NOMBRE']=='NASDAQ 100']['PRECIO'].plot(color = 'red',label = 'NASDAQ')
df[df['NOMBRE']=='NYSE COMPOSITE']['PRECIO'].plot(color = 'cyan',label = 'NYSE')
df[df['NOMBRE']=='S&P 500']['PRECIO'].plot(color = 'purple',label = 'S&P 500')
df[df['NOMBRE']=='GOLD SPOT US DOLLAR']['PRECIO'].plot(color = 'green',label = 'GOLD')
plt.legend(loc='upper left')
plt.xticks(rotation = 45);
